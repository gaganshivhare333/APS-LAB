# %% [markdown]
# <a href="https://colab.research.google.com/github/gaganshivhare333/APS-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 2, 'C': 7, 'E':12},
'B': {'D': 2},
'C': {'B': 3, 'D': 1, 'E':2},
'D': {'F':2},
'E': {'A':4,'G':7,},
'F': {'G':2},
'G': {'D':1}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 2
# Distance from A to C = 7
# Distance from A to D = 4
# Distance from A to E = 9
# Distance from A to F = 6
# Distance from A to G = 8

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra_with_path(graph, start):

    distances = {node: float('inf') for node in graph}
    paths = {node: [] for node in graph}

    distances[start] = 0
    paths[start] = [start]


    priority_queue = [(0, start)]
    visited = set()

    while priority_queue:
        current_distance, current_node = heapq.heappop(priority_queue)

        if current_node in visited:
            continue
        visited.add(current_node)

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight


            if distance < distances[neighbor]:
                distances[neighbor] = distance
                paths[neighbor] = paths[current_node] + [neighbor]
                heapq.heappush(priority_queue, (distance, neighbor))

    return distances, paths

graph = {
    'A': {'B': 2, 'C': 7, 'E': 12},
    'B': {'D': 2},
    'C': {'B': 3, 'D': 1, 'E': 2},
    'D': {'F': 2, 'H': 5},
    'E': {'A': 4, 'G': 7},
    'F': {'G': 2, 'I': 3},
    'G': {'D': 1},
    'H': {'I': 1},
    'I': {'E': 1}
}

source = input("Enter the source node (e.g., A, B, C...): ").upper()

if source in graph:
    distances, paths = dijkstra_with_path(graph, source)

    print(f"\n--- Shortest Paths from {source} ---")
    for node in distances:

        path_str = " -> ".join(paths[node])
        print(f"To {node}: Distance = {distances[node]} | Path: {path_str}")
else:
    print("Node not found in graph.")
# Out:
# Enter the source node (e.g., A, B, C...): A
#
# --- Shortest Paths from A ---
# To A: Distance = 0 | Path: A
# To B: Distance = 2 | Path: A -> B
# To C: Distance = 7 | Path: A -> C
# To D: Distance = 4 | Path: A -> B -> D
# To E: Distance = 9 | Path: A -> C -> E
# To F: Distance = 6 | Path: A -> B -> D -> F
# To G: Distance = 8 | Path: A -> B -> D -> F -> G
# To H: Distance = 9 | Path: A -> B -> D -> H
# To I: Distance = 9 | Path: A -> B -> D -> F -> I
